# %%
import pvdeg
import xarray as xr
import os
import glob

import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
files = glob.glob(os.path.abspath("/projects/pvsoiling/pvdeg/analysis/pvrw2025/diffuse_stow/tmy/*.nc"))

loaded_tmy = xr.open_mfdataset(files)

# %%
fig, ax = plt.subplots(figsize=(12, 8), subplot_kw={'projection': ccrs.LambertConformal()})

# Plot using pvdeg's plot_sparse_analysis
fig, ax, im = pvdeg.geospatial.plot_sparse_analysis(
    loaded_tmy,
    "delta_mov (%)",
    resolution=400j,
    method="nearest",
    ax=ax,
    cmap="viridis_r"
)

# Set the title on the axis
ax.set_title("delta_mov (%)")

# Save the plot with high resolution
plt.savefig("delta_mov_percent_r.png", dpi=800)

# Show the plot
plt.show()

# %%
#fig, ax = plt.subplots(figsize=(12, 8))
fig, ax = plt.subplots(figsize=(12, 8), subplot_kw={'projection': ccrs.LambertConformal()})

# Plot using pvdeg's plot_sparse_analysis
fig, ax, im = pvdeg.geospatial.plot_sparse_analysis(
    loaded_tmy,
    "energy_TT (Wh)",
    resolution=400j,
    method="nearest",
    ax=ax
)

# Set the title on the axis
ax.set_title("energy_TT (kWh)")

# Save the plot with high resolution
plt.savefig("energy_TT_kwh.png", dpi=800)

# Show the plot
plt.show()

# %%
loaded_tmy["

# %%
five_min_loaded = xr.open_mfdataset("/projects/pvsoiling/pvdeg/analysis/pvrw2025/diffuse_stow/5min/*.nc")

# %%
fig, ax = plt.subplots(figsize=(12, 8), subplot_kw={'projection': ccrs.LambertConformal()})

# Plot using pvdeg's plot_sparse_analysis
fig, ax, im = pvdeg.geospatial.plot_sparse_analysis(
    five_min_loaded,
    "delta_en (%)",
    resolution=200j,
    method="nearest",
    ax=ax,
    cmap="viridis"
)

# Set the title on the axis
ax.set_title("delta_mov (%)")

# Save the plot with high resolution
plt.savefig("delta_en_percent_5min_percent.png", dpi=800)

# Show the plot
plt.show()

# %%
five_min_loaded
# Out:
# <xarray.Dataset> Size: 136kB
# Dimensions:         (latitude: 47, longitude: 119)
# Coordinates:
#   * latitude        (latitude) float64 376B 25.14 25.66 26.18 ... 48.54 49.06
#   * longitude       (longitude) float64 952B -124.2 -123.7 ... -68.05 -67.53
# Data variables:
#     delta_en (%)    (latitude, longitude) float64 45kB dask.array<chunksize=(26, 14), meta=np.ndarray>
#     delta_mov (%)   (latitude, longitude) float64 45kB dask.array<chunksize=(26, 14), meta=np.ndarray>
#     energy_TT (Wh)  (latitude, longitude) float64 45kB dask.array<chunksize=(26, 14), meta=np.ndarray>
